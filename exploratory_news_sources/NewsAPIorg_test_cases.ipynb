# %% [markdown]
# # Test queries - NewsAPI

# %% [markdown]
# This Jupyter Notebook uses NewsAPI (https://newsapi.org/) to get articles for different test cases from Google News.
#
#
# Author: Dominik Wielath (dominik.wielath@gmail.com)
#
# DIME Artificial Intelligence (DIME AI) - World Bank Group
#
# Date: 2024-07-04

# %%
from newsapi import NewsApiClient
import pandas as pd

newsapi = NewsApiClient(api_key='786c49f9d0be4ddda5108932408aa10d')

# %% [markdown]
# ## Test Cases

# %% [markdown]
# ### Yambio

# %% [markdown]
# 4. 06/16/2024 to 06/30/2024 - "Yambio" - English articles only

# %%
results = newsapi.get_everything(q='Yambio', from_param='2024-06-16', to='2024-06-30', language='en')

# %%
count = results["totalResults"]
print(f"{count} results for the query")
# Out:
# 4 results for the query

# %%
pd.DataFrame(data=results["articles"])
# Out:
#                                        source          author  \
# 0  {'id': None, 'name': 'Globalsecurity.org'}       John Pike
# 1           {'id': None, 'name': '[Removed]'}            None
# 2           {'id': None, 'name': 'People.cn'}        F_300952
# 3             {'id': None, 'name': 'UN News'}  United Nations
#
#                                                title  \
# 0  Peacekeepers in South Sudan sent to protect ci...
# 1                                          [Removed]
# 2  Peacekeepers in South Sudan sent to protect ci...
# 3  Daily Press Briefing by the Office of the Spok...
#
#                                          description  \
# 0  UN peacekeepers in South Sudan have intensifie...
# 1                                          [Removed]
# 2  UNITED NATIONS, June 21 (Xinhua) -- UN peaceke...
# 3  The Office of the United Nations High Commissi...
#
#                                                  url urlToImage  \
# ...

# %% [markdown]
# 5. 01/01/2000 to 06/30/2024	- Yambio - English articles only

# %%
#results = newsapi.get_everything(q='Yambio', from_param='2000-01-01', to='2024-06-30', language='en')
#count = results["totalResults"]
#print(f"{count} results for the query")

# %%
#pd.DataFrame(data=results["articles"])

# %% [markdown]
# 6. 01/01/2000 to 06/30/2024	- "Yambio and (political turmoil)" - English articles only

# %%
#results = newsapi.get_everything(q="Yambio 'political turmoil'", from_param='2000-01-01', to='2024-06-30', language='en')
#count = results["totalResults"]
#print(f"{count} results for the query")

# %%
#pd.DataFrame(data=results["articles"])

# %% [markdown]
# ### Lagos

# %% [markdown]
# 7. 06/16/2024 to 06/30/2024	- Nigeria - "Lagos" - English articles only

# %% [markdown]
# 8. 01/01/2000 to 06/30/2024 - Nigeria - "Lagos" - English articles only

# %% [markdown]
# 9. 01/01/2000 to 06/30/2024	- Nigeria	- "Lagos 'food prices'"	- English articles only

# %% [markdown]
# 10. 06/16/2024 to 06/30/2024 - Nigeria - "Lagos 'food prices'" - English articles only

# %% [markdown]
# 11. 06/16/2024 to 06/30/2024 - "Lagos" - English articles only

# %%
results = newsapi.get_everything(q='Lagos', from_param='2024-06-16', to='2024-06-30', language='en', page=1)

# %%
#results2 = newsapi.get_everything(q='Lagos', from_param='2024-06-16', to='2024-06-30', language='en', page=2)
#results3 = newsapi.get_everything(q='Lagos', from_param='2024-06-16', to='2024-06-30', language='en', page=3)
#results4 = newsapi.get_everything(q='Lagos', from_param='2024-06-16', to='2024-06-30', language='en', page=4)
#results5 = newsapi.get_everything(q='Lagos', from_param='2024-06-16', to='2024-06-30', language='en', page=5)
#results6 = newsapi.get_everything(q='Lagos', from_param='2024-06-16', to='2024-06-30', language='en', page=6)
#results7 = newsapi.get_everything(q='Lagos', from_param='2024-06-16', to='2024-06-30', language='en', page=7)
#results8 = newsapi.get_everything(q='Lagos', from_param='2024-06-16', to='2024-06-30', language='en', page=8)
#results9 = newsapi.get_everything(q='Lagos', from_param='2024-06-16', to='2024-06-30', language='en', page=9)

# %%
count = results["totalResults"]
print(f"{count} results for the query")
# Out:
# 873 results for the query

# %% [markdown]
# 12. 06/16/2024 to 06/30/2024 - "Lagos 'food prices'" - English articles only

# %%
results = newsapi.get_everything(q="Lagos 'food prices'", from_param='2024-06-16', to='2024-06-30', language='en', page=1)

# %%
count = results["totalResults"]
print(f"{count} results for the query")
# Out:
# 27 results for the query

# %% [markdown]
# ### Jinja

# %% [markdown]
# 13. 01/01/2000 to 06/30/2024 - Uganda - "Jinja" - English articles only

# %% [markdown]
# 14.	06/16/2024 to 06/30/2024 - Uganda - "Jinja" - English articles only

# %% [markdown]
# 15.	01/01/2000 to 06/30/2024 - Uganda - "Jinja 'low rainfall'" - English articles only

# %% [markdown]
# 16.	06/16/2024 to 06/30/2024 - Uganda - "Jinja 'low rainfall'" - English articles only

# %% [markdown]
# 17. 06/16/2024 to 06/30/2024 - Uganda -	English articles only

# %% [markdown]
# 18. 06/16/2024 to 06/30/2024 - Uganda - "Uganda"- English articles only

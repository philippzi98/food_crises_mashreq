# %% [markdown]
# # Test queries - Google News Metadata using GNews

# %% [markdown]
# This Jupyter Notebook scrapes metadata for different test cases from Google News using the GNews library (https://github.com/ranahaani/GNews).
#
#
# Author: Dominik Wielath (dominik.wielath@gmail.com)
#
# DIME Artificial Intelligence (DIME AI) - World Bank Group
#
# Date: 2024-07-04

# %%
from utilities import *

data_path = "../data/"

# %% [markdown]
# ## Test cases

# %% [markdown]
# ### Yambio

# %% [markdown]
# 4. 06/16/2024 to 06/30/2024 - "Yambio" - English articles only

# %%
# Specify the search query
start_date = dt.date(2024, 6, 16)
end_date_last = dt.date(2024, 6, 30)
query_word = 'Yambio'
language = "english"

delta = None

# %%
article_metadata = get_news_data(query_word=query_word, start_date=start_date, end_date_last=end_date_last, language = language, delta = delta)
#save_metadata_table(article_metadata=article_metadata, query_word=query_word, start_date=start_date, end_date_last=end_date_last, data_path=data_path)
# Out:
# 2024-06-16 to 2024-06-30: 4 articles retrieved.
#
# Removing duplicates...
# Total articles retrieved: 4 for query word 'Yambio' from 2024-06-16 to 2024-06-30
# Metadata successfully saved to ../data/meta_Yambio__6_16_2024__6_30_2024.csv

# %% [markdown]
# 5. 01/01/2000 to 06/30/2024	- Yambio - English articles only

# %%
# Specify the search query
start_date = dt.date(2000, 1, 1)
end_date_last = dt.date(2024, 6, 30)
query_word = 'Yambio'
language = "english"

delta = 'y'

# %%
article_metadata = get_news_data(query_word=query_word, start_date=start_date, end_date_last=end_date_last, language = language, delta = delta)
#ave_metadata_table(article_metadata=article_metadata, query_word=query_word, start_date=start_date, end_date_last=end_date_last, data_path=data_path)
# Out:
# 2000-01-01 to 2001-01-01: 0 articles retrieved.
# 2001-01-01 to 2002-01-01: 0 articles retrieved.
# 2002-01-01 to 2003-01-01: 0 articles retrieved.
# 2003-01-01 to 2004-01-01: 4 articles retrieved.
# 2004-01-01 to 2005-01-01: 2 articles retrieved.
# 2005-01-01 to 2006-01-01: 8 articles retrieved.
# 2006-01-01 to 2007-01-01: 5 articles retrieved.
# 2007-01-01 to 2008-01-01: 9 articles retrieved.
# 2008-01-01 to 2009-01-01: 9 articles retrieved.
# 2009-01-01 to 2010-01-01: 9 articles retrieved.
# 2010-01-01 to 2011-01-01: 19 articles retrieved.
# 2011-01-01 to 2012-01-01: 14 articles retrieved.
# 2012-01-01 to 2013-01-01: 9 articles retrieved.
# 2013-01-01 to 2014-01-01: 9 articles retrieved.
# 2014-01-01 to 2015-01-01: 10 articles retrieved.
# 2015-01-01 to 2016-01-01: 14 articles retrieved.
# 2016-01-01 to 2017-01-01: 63 articles retrieved.
# 2017-01-01 to 2018-01-01: 23 articles retrieved.
# 2018-01-01 to 2019-01-01: 25 articles retrieved.
# ...

# %% [markdown]
# 6. 01/01/2000 to 06/30/2024	- "Yambio and (political turmoil)" - English articles only

# %%
# Specify the search query
start_date = dt.date(2000, 1, 1)
end_date_last = dt.date(2024, 6, 30)
query_word = "Yambio 'political turmoil'"
language = "english"

delta = None

# %%
article_metadata = get_news_data(query_word=query_word, start_date=start_date, end_date_last=end_date_last, language = language, delta = delta)
#save_metadata_table(article_metadata=article_metadata, query_word=query_word, start_date=start_date, end_date_last=end_date_last, data_path=data_path)
# Out:
# 2000-01-01 to 2024-06-30: 6 articles retrieved.
#
# Removing duplicates...
# Total articles retrieved: 6 for query word 'Yambio 'political turmoil'' from 2000-01-01 to 2024-06-30

# %% [markdown]
# ### Lagos

# %% [markdown]
# 7. 06/16/2024 to 06/30/2024	- Nigeria - "Lagos" - English articles only

# %%
# Specify the search query
start_date = dt.date(2024, 6, 16)
end_date_last = dt.date(2024, 6, 30)
country = 'NG'
query_word = 'Lagos'
language = "english"

delta = "d"

# %%
article_metadata = get_news_data(query_word=query_word, start_date=start_date, end_date_last=end_date_last, country = country, language = language, delta = delta)
#save_metadata_table(article_metadata=article_metadata, query_word=query_word, start_date=start_date, end_date_last=end_date_last, county=country, data_path=data_path)
# Out:
# Reduce the timedelta, from 2024-06-16 to 2024-06-17 over 100 observations
# 2024-06-16 to 2024-06-17: 100 articles retrieved.
# 2024-06-17 to 2024-06-18: 99 articles retrieved.
# Reduce the timedelta, from 2024-06-18 to 2024-06-19 over 100 observations
# 2024-06-18 to 2024-06-19: 100 articles retrieved.
# Reduce the timedelta, from 2024-06-19 to 2024-06-20 over 100 observations
# 2024-06-19 to 2024-06-20: 100 articles retrieved.
# Reduce the timedelta, from 2024-06-20 to 2024-06-21 over 100 observations
# 2024-06-20 to 2024-06-21: 100 articles retrieved.
# 2024-06-21 to 2024-06-22: 99 articles retrieved.
# 2024-06-22 to 2024-06-23: 99 articles retrieved.
# 07/04/2024 02:59:32 PM - ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# 2024-06-23 to 2024-06-24: 0 articles retrieved.
# Reduce the timedelta, from 2024-06-24 to 2024-06-25 over 100 observations
# 2024-06-24 to 2024-06-25: 100 articles retrieved.
# ...

# %% [markdown]
# 8. 01/01/2000 to 06/30/2024 - Nigeria - "Lagos" - English articles only

# %%
start_date = dt.date(2000, 1, 1)
end_date_last = dt.date(2024, 6, 30)
country = 'NG'
query_word = 'Lagos'
language = "english"

delta = "d"

# %%
article_metadata = get_news_data(query_word=query_word, start_date=start_date, end_date_last=end_date_last, country = country, language=language, delta = delta)
#save_metadata_table(article_metadata=article_metadata, query_word=query_word, start_date=start_date, end_date_last=end_date_last, county=country, data_path=data_path)

# %% [markdown]
# 9. 01/01/2000 to 06/30/2024	- Nigeria	- "Lagos 'food prices'"	- English articles only

# %%
start_date = dt.date(2000, 1, 1)
end_date_last = dt.date(2024, 6, 30)
country = 'NG'
query_word = "Lagos 'food prices'" 
language = "english"

delta = "m"

# %%
article_metadata = get_news_data(query_word=query_word, start_date=start_date, end_date_last=end_date_last, country = country, language = language, delta = delta)
#save_metadata_table(article_metadata=article_metadata, query_word=query_word, start_date=start_date, end_date_last=end_date_last, county=country, data_path=data_path)
# Out:
# 2000-01-01 to 2000-02-01: 0 articles retrieved.
# 2000-02-01 to 2000-03-01: 0 articles retrieved.
# 2000-03-01 to 2000-04-01: 0 articles retrieved.
# 2000-04-01 to 2000-05-01: 0 articles retrieved.
# 2000-05-01 to 2000-06-01: 0 articles retrieved.
# 2000-06-01 to 2000-07-01: 0 articles retrieved.
# 2000-07-01 to 2000-08-01: 0 articles retrieved.
# 2000-08-01 to 2000-09-01: 0 articles retrieved.
# 2000-09-01 to 2000-10-01: 0 articles retrieved.
# 2000-10-01 to 2000-11-01: 0 articles retrieved.
# 2000-11-01 to 2000-12-01: 0 articles retrieved.
# 2000-12-01 to 2001-01-01: 0 articles retrieved.
# 2001-01-01 to 2001-02-01: 0 articles retrieved.
# 2001-02-01 to 2001-03-01: 0 articles retrieved.
# 2001-03-01 to 2001-04-01: 0 articles retrieved.
# 2001-04-01 to 2001-05-01: 0 articles retrieved.
# 2001-05-01 to 2001-06-01: 0 articles retrieved.
# 2001-06-01 to 2001-07-01: 0 articles retrieved.
# 2001-07-01 to 2001-08-01: 0 articles retrieved.
# 2001-08-01 to 2001-09-01: 0 articles retrieved.
# ...

# %% [markdown]
# 10. 06/16/2024 to 06/30/2024 - Nigeria - "Lagos 'food prices'" - English articles only

# %%
start_date = dt.date(2024, 6, 16)
end_date_last = dt.date(2024, 6, 30)
country = 'NG'
query_word = "Lagos 'food prices'" 
language = "english"

delta = None

# %%
article_metadata = get_news_data(query_word=query_word, start_date=start_date, end_date_last=end_date_last, country = country, language = language, delta = delta)
#save_metadata_table(article_metadata=article_metadata, query_word=query_word, start_date=start_date, end_date_last=end_date_last, county=country, data_path=data_path)
# Out:
# 2024-06-16 to 2024-06-30: 64 articles retrieved.
#
# Removing duplicates...
# Total articles retrieved: 64 for query word 'Lagos 'food prices'' from 2024-06-16 to 2024-06-30

# %% [markdown]
# 11. 06/16/2024 to 06/30/2024 - "Lagos" - English articles only

# %%
start_date = dt.date(2024, 6, 16)
end_date_last = dt.date(2024, 6, 30)
country = None
query_word = "Lagos" 
language = "english"

delta = "d"

# %%
article_metadata = get_news_data(query_word=query_word, start_date=start_date, end_date_last=end_date_last, country=country, language=language, delta = delta)
#save_metadata_table(article_metadata=article_metadata, query_word=query_word, start_date=start_date, end_date_last=end_date_last, county=country, data_path=data_path)
# Out:
# 2024-06-16 to 2024-06-17: 99 articles retrieved.
# 2024-06-17 to 2024-06-18: 99 articles retrieved.
# Reduce the timedelta, from 2024-06-18 to 2024-06-19 over 100 observations
# 2024-06-18 to 2024-06-19: 100 articles retrieved.
# Reduce the timedelta, from 2024-06-19 to 2024-06-20 over 100 observations
# 2024-06-19 to 2024-06-20: 100 articles retrieved.
# Reduce the timedelta, from 2024-06-20 to 2024-06-21 over 100 observations
# 2024-06-20 to 2024-06-21: 100 articles retrieved.
# 2024-06-21 to 2024-06-22: 99 articles retrieved.
# 2024-06-22 to 2024-06-23: 99 articles retrieved.
# Reduce the timedelta, from 2024-06-23 to 2024-06-24 over 100 observations
# 2024-06-23 to 2024-06-24: 100 articles retrieved.
# Reduce the timedelta, from 2024-06-24 to 2024-06-25 over 100 observations
# 2024-06-24 to 2024-06-25: 100 articles retrieved.
# 2024-06-25 to 2024-06-26: 99 articles retrieved.
# 2024-06-26 to 2024-06-27: 95 articles retrieved.
# 2024-06-27 to 2024-06-28: 98 articles retrieved.
# ...

# %% [markdown]
# 12. 06/16/2024 to 06/30/2024 - "Lagos 'food prices'" - English articles only

# %%
start_date = dt.date(2024, 6, 16)
end_date_last = dt.date(2024, 6, 30)
country = None
query_word = "Lagos 'food prices'" 
language = "english"

delta = None

# %%
article_metadata = get_news_data(query_word=query_word, start_date=start_date, end_date_last=end_date_last, country=country, language=language, delta = delta)
#save_metadata_table(article_metadata=article_metadata, query_word=query_word, start_date=start_date, end_date_last=end_date_last, county=country, data_path=data_path)
# Out:
# 2024-06-16 to 2024-06-30: 66 articles retrieved.
#
# Removing duplicates...
# Total articles retrieved: 66 for query word 'Lagos 'food prices'' from 2024-06-16 to 2024-06-30

# %% [markdown]
# ### Jinja

# %% [markdown]
# 13. 01/01/2000 to 06/30/2024 - Uganda - "Jinja" - English articles only

# %%
start_date = dt.date(2000, 1, 1)
end_date_last = dt.date(2024, 6, 30)
country = "UG"
query_word = "Jinja" 
language = "english"

delta = "m"

# %%
article_metadata = get_news_data(query_word=query_word, start_date=start_date, end_date_last=end_date_last, country=country, language=language, delta = delta)
#save_metadata_table(article_metadata=article_metadata, query_word=query_word, start_date=start_date, end_date_last=end_date_last, county=country, data_path=data_path)

# %% [markdown]
# 14.	06/16/2024 to 06/30/2024 - Uganda - "Jinja" - English articles only

# %%
start_date = dt.date(2024, 6, 16)
end_date_last = dt.date(2024, 6, 30)
country = "UG"
query_word = "Jinja" 
language = "english"

delta = None

# %%
article_metadata = get_news_data(query_word=query_word, start_date=start_date, end_date_last=end_date_last, country=country, language=language, delta = delta)
#save_metadata_table(article_metadata=article_metadata, query_word=query_word, start_date=start_date, end_date_last=end_date_last, county=country, data_path=data_path)
# Out:
# 2024-06-16 to 2024-06-30: 44 articles retrieved.
#
# Removing duplicates...
# Total articles retrieved: 44 for query word 'Jinja' from 2024-06-16 to 2024-06-30

# %% [markdown]
# 15.	01/01/2000 to 06/30/2024 - Uganda - "Jinja 'low rainfall'" - English articles only

# %%
start_date = dt.date(2000, 1, 1)
end_date_last = dt.date(2024, 6, 30)
country = "UG"
query_word = "Jinja 'low rainfall'" 
language = "english"

delta = None

# %%
article_metadata = get_news_data(query_word=query_word, start_date=start_date, end_date_last=end_date_last, country=country, language=language, delta = delta)
#save_metadata_table(article_metadata=article_metadata, query_word=query_word, start_date=start_date, end_date_last=end_date_last, county=country, data_path=data_path)
# Out:
# 2000-01-01 to 2024-06-30: 7 articles retrieved.
#
# Removing duplicates...
# Total articles retrieved: 7 for query word 'Jinja 'low rainfall'' from 2000-01-01 to 2024-06-30

# %% [markdown]
# 16.	06/16/2024 to 06/30/2024 - Uganda - "Jinja 'low rainfall'" - English articles only

# %%
start_date = dt.date(2024, 6, 16)
end_date_last = dt.date(2024, 6, 30)
country = "UG"
query_word = "Jinja 'low rainfall'" 
language = "english"

delta = None

# %%
article_metadata = get_news_data(query_word=query_word, start_date=start_date, end_date_last=end_date_last, country=country, language=language, delta = delta)
#save_metadata_table(article_metadata=article_metadata, query_word=query_word, start_date=start_date, end_date_last=end_date_last, county=country, data_path=data_path)

# %% [markdown]
# 17. 06/16/2024 to 06/30/2024 - Uganda -	English articles only

# %%
start_date = dt.date(2024, 6, 16)
end_date_last = dt.date(2024, 6, 30)
country = "UG"
query_word = None
language = "english"

delta = None

# %%
#article_metadata = get_news_data(query_word=query_word, start_date=start_date, end_date_last=end_date_last, country=country, language=language, delta = delta)
#save_metadata_table(article_metadata=article_metadata, query_word=query_word, start_date=start_date, end_date_last=end_date_last, county=country, data_path=data_path)

# %% [markdown]
# 18. 06/16/2024 to 06/30/2024 - Uganda - "Uganda"- English articles only

# %%
start_date = dt.date(2024, 6, 16)
end_date_last = dt.date(2024, 6, 30)
country = "UG"
query_word = "Uganda"
language = "english"

delta = None

# %%
#article_metadata = get_news_data(query_word=query_word, start_date=start_date, end_date_last=end_date_last, country=country, language=language, delta = delta)
#save_metadata_table(article_metadata=article_metadata, query_word=query_word, start_date=start_date, end_date_last=end_date_last, county=country, data_path=data_path)
